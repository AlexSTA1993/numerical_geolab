# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
np.random.seed(1)
from mpl_toolkits.mplot3d import Axes3D
import scipy.sparse as sp
from scipy.linalg import solve as scsolve
import time
plt.rcParams["figure.figsize"] = (5,15)
from scipy.integrate import solve_ivp

import warnings
from scipy.sparse import (spdiags, SparseEfficiencyWarning, csc_matrix,
    csr_matrix, isspmatrix, dok_matrix, lil_matrix, bsr_matrix)
warnings.simplefilter('ignore',SparseEfficiencyWarning)

# %%
# Coordinates and Connectivity matrices: 
xmax=10;ymax=10;zmax=10 # box's dimensions (in meters)
V = xmax*ymax*zmax
nx = 10
ny = nx; nz = (nx)
nx+=1; ny+=1;nz+=1
print("nx =",nx-1," ny =",ny-1," nz =",nz-1)
# Out:
# nx = 10  ny = 10  nz = 10

# %%
def ss_el_pl(t, y, de, params, gl_tol, tol_e, tol_s):
    YM, k, H = params
    if yieldf(y[1], params) >=  gl_tol * tol_s and y[3] >= -gl_tol:
        g = de*np.array([[(YM*H)/(YM+H)],#[-(YM**2)/(YM+H)+YM],
                     [0.],
                     [YM/(YM+H)],
                     [YM/((YM+H)*np.sign(y[1]))]])
    else:
        g = de*np.array([[YM],
                     [YM],
                     [0.],
                     [0.]])
    return g.flatten()


def yieldf(chi, params):
    return np.absolute(chi) - params[1]


def hyper_increment(DEpsilon, state, params):
    pl=False
    y0, t0 = state, 0.0
    tol_e = 1.e+0
    tol_s = 1.e-0
    gl_tol = 1.e-8
    cd = 5e-1
    statetdt = solve_ivp(fun=lambda t, y: ss_el_pl(t,y,DEpsilon,params,gl_tol,tol_e,tol_s), t_span=[0.,1.], y0=y0,
                         method='RK23',rtol=1.e-10, atol= gl_tol*np.array([tol_s,tol_s,tol_e,tol_e]))
    statetdt = statetdt.y[:,-1:].flatten()
    if statetdt[3]>=-gl_tol*tol_e: 
        ddsdde=np.array([(1.-cd)*params[0]*params[2]/(params[0]+params[2])+cd*params[0]])
    else: ddsdde=np.array(params[0])
    return statetdt,ddsdde

def plot_nodes(coor):
    plt.plot(coor[:,0],coor[:,1],color='red',linewidth=0, marker='o',markersize=3, alpha=0.7)
    plt.show()
    return

colors = ['red', 'green', 'blue']

def plot_elems(cooneM,coor,group,plot3D=False):
    if plot3D==True: 
        fig = plt.figure()
        ax = fig.gca(projection='3d')
    else:
        fig, ax = plt.subplots()
    for i in range(cooneM.shape[0]):
        cons=cooneM[i]
        p1 = coor[cons[0]]; p2 = coor[cons[1]]
        if plot3D==True:
#             print(group[i])
            color=colors[group[i]]
            ax.plot([p1[0],p2[0]],[p1[1],p2[1]],[p1[2],p2[2]],color=color,linewidth=1, marker='o',markersize=5)
            ax.set_zlabel("z")
        else:
            ax.plot([p1[0],p2[0]],[p1[1],p2[1]],'r-',linewidth=1, marker='o',markersize=5, alpha=0.7)
#         print([p1[0],p2[0]],[p1[1],p2[1]])
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    plt.show()
    return

def plot_sol(cooneM,coor,solU,show_old=True,plot3D=False):
    if plot3D==True: 
        fig = plt.figure()
        ax = fig.gca(projection='3d')
    else:
        fig, ax = plt.subplots()
    coorp=coor+solU
    
    for cons in cooneM:
        if show_old==True:
            p1 = coor[cons[0]]
            p2 = coor[cons[1]]
            if plot3D==True:
                ax.plot([p1[0],p2[0]],[p1[1],p2[1]],[p1[2],p2[2]],'r-',linewidth=1, marker='o',markersize=5)
                ax.set_zlabel("z")
            else:
                ax.plot([p1[0],p2[0]],[p1[1],p2[1]],'r-',linewidth=1, marker='o',markersize=5, alpha=0.7)
        
        p1 = coorp[cons[0]]; p2 = coorp[cons[1]]
        if plot3D==True:
            ax.plot([p1[0],p2[0]],[p1[1],p2[1]],[p1[2],p2[2]],'b-',linewidth=1, marker='o',markersize=5)
            ax.set_zlabel("z")
        else:
            ax.plot([p1[0],p2[0]],[p1[1],p2[1]],'b-',linewidth=1, marker='o',markersize=5, alpha=0.7)
#         print([p1[0],p2[0]],[p1[1],p2[1]])
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    plt.show()
    return


s=0.
dhx=0.;dhy=0.;dhz=0.
if nx>1: dhx=xmax/(nx-1)
if ny>1: dhy=ymax/(ny-1)
if nz>1: dhz=zmax/(nz-1)

def nop(i,j,k):
    return j+i*ny+k*nx*ny
coorM=np.zeros((nx*ny*nz,3))
nels=(nx*ny*nz)**2

conneM=np.zeros((nels,2),dtype=np.uint32)

el=0
perbc=[]
for k in range(nz):
    for i in range(nx):
        for j in range(ny):
            # periodic connectivity
            
            if i==nx-1 and j!=ny-1: perbc.append([nop(i,j,k),nop(i-nx+1,j,k)])
            
            if j==ny-1: perbc.append([nop(i,j,k),nop(i,j-ny+1,k)])
            
            if k==nz-1 and i!=nx-1 and j!=ny-1: perbc.append([nop(i,j,k),nop(i,j,k-nz+1)])
            
            # nodes'coordinates
            perturbation=np.array([np.random.uniform(-s,s)*dhx,
                                       np.random.uniform(-s,s)*dhy,
                                       np.random.uniform(-s,s)*dhz])
            perturbation=np.multiply(perturbation,np.array(np.sign([nx-1,ny-1,nz-1])))
            coorM[nop(i,j,k)]=np.array([i*dhx,j*dhy,k*dhz])+perturbation
            if  i==nx-1: coorM[nop(i,j,k)]=coorM[nop(0,j,k)]+np.array([dhx*(nx-1),0,0])
            if  j==ny-1: coorM[nop(i,j,k)]=coorM[nop(i,0,k)]+np.array([0,dhy*(ny-1),0])
            if  k==nz-1: coorM[nop(i,j,k)]=coorM[nop(i,j,0)]+np.array([0,0,dhz*(nz-1)])
            
            # nodes' connectivity - elements
            if i<nx-1:
                conneM[el]=np.array([nop(i,j,k),nop(i+1,j,k)]); el+=1
            if j<ny-1: 
                conneM[el]=np.array([nop(i,j,k),nop(i,j+1,k)]); el+=1
            if i<nx-1 and j<ny-1: 
                conneM[el]=np.array([nop(i,j,k),nop(i+1,j+1,k)]); el+=1 
            if i>0 and j<ny-1: 
                conneM[el]=np.array([nop(i,j,k),nop(i-1,j+1,k)]); el+=1   

            if k>0:
                conneM[el]=np.array([nop(i,j,k),nop(i,j,k-1)]); el+=1
                if j<ny-1: 
                    conneM[el]=np.array([nop(i,j,k),nop(i,j+1,k-1)]); el+=1   
                if j>0: 
                    conneM[el]=np.array([nop(i,j,k),nop(i,j-1,k-1)]); el+=1   
                if i<nx-1: 
                    conneM[el]=np.array([nop(i,j,k),nop(i+1,j,k-1)]); el+=1
                if i>0: 
                    conneM[el]=np.array([nop(i,j,k),nop(i-1,j,k-1)]); el+=1
                         
                
conneM=conneM[:el]

groupM=np.zeros((el),dtype=np.uint32)
toleps=1e-4
e1=np.array([1.,0,0]);e2=np.array([0,1.,0]);e3=np.array([0,0,1.])
for i in range(el):    
    a,b=coorM[conneM[i]]
    ab=b+a; ab=ab/np.linalg.norm(ab)
#     print(a,b)
    
    if np.abs(a[2]-b[2])<=toleps and (np.abs(a[2]-0)<=toleps or np.abs(a[2]-zmax)<=toleps):
        groupM[i]=1
    if np.abs(a[1]-b[1])<=toleps and (np.abs(a[1]-0)<=toleps or np.abs(a[1]-ymax)<=toleps):
        groupM[i]=1
    if np.abs(a[0]-b[0])<=toleps and (np.abs(a[0]-0)<=toleps or np.abs(a[0]-xmax)<=toleps):
        groupM[i]=1
    if ((np.abs(a[0]-b[0])<=toleps and (np.abs(a[0]-0)<=toleps or np.abs(a[0]-xmax)<=toleps)) and 
       (np.abs(a[1]-b[1])<=toleps and (np.abs(a[1]-0)<=toleps or np.abs(a[1]-ymax)<=toleps)) ):
        groupM[i]=2
    if ((np.abs(a[0]-b[0])<=toleps and (np.abs(a[0]-0)<=toleps or np.abs(a[0]-xmax)<=toleps)) and 
       (np.abs(a[2]-b[2])<=toleps and (np.abs(a[2]-0)<=toleps or np.abs(a[2]-zmax)<=toleps))) :
        groupM[i]=2
    if ((np.abs(a[1]-b[1])<=toleps and (np.abs(a[1]-0)<=toleps or np.abs(a[1]-ymax)<=toleps)) and
       (np.abs(a[2]-b[2])<=toleps and (np.abs(a[2]-0)<=toleps or np.abs(a[2]-zmax)<=toleps))) :
        groupM[i]=2

perbc0=None

class lattice_element:
    """
    Class for a fault segment
    (all angles in radians)
    """
    def __init__(self,connection,coordinates,iid,param):
        self.coordA=coordinates[0];self.coordB=coordinates[1]
        self.nodeA=connection[0];self.nodeB=connection[1]
        dx=self.coordA-self.coordB
        self.L=np.sum(dx**2)**.5
        self.nv=dx/self.L
        a=np.expand_dims(self.nv, axis=0)
        self.nvinvj=np.matmul(a.transpose(),a)
        self.id=iid
        self.param=param[:3]
        self.S = param[3]

    def elements_jac_rhs(self,dU,svars):
        deps=self.get_eps(dU)
        force_t=svars[0]
        force_tdt,svars_tdt,ddsdde=self.material_increment(deps,svars)
        return (force_tdt-force_t)*self.S*self.nv, ddsdde*self.S*self.nvinvj/self.L, svars_tdt
    
    def get_eps(self,dU):
        dUaxial=np.dot(dU,self.nv)
        deps=dUaxial/self.L
        return deps    
    
    def material_increment(self,deps,svars):
        '''Spring material -> to overide later'''
        #output Dsg, svars_tdt, F_tdt, D_tdt
        svarstdt = svars.copy()
        alphat = svarstdt[2].copy()
        
        sol,ddsdde=hyper_increment(deps,svarstdt[:4],self.param)
        sigmatdt,Xtdt,alphatdt,l=sol
        svarstdt[0] = sigmatdt
        svarstdt[1] = Xtdt
        svarstdt[2] = alphatdt
        epsilontdt = deps+svarstdt[4]
        svarstdt[4] = epsilontdt
        svarstdt[5] = self.S*self.L*(0.5*self.param[0]*(epsilontdt-alphatdt)**2+0.5*self.param[2]*alphatdt**2)
        svarstdt[6] = self.S*self.param[1]*self.L*np.abs(alphatdt-alphat)
        svarstdt[7] = self.L
        svarstdt[8:11] = sigmatdt*self.nv
        return sigmatdt, svarstdt, ddsdde
   
    
class lattice:
    def __init__(self,coordinates,connectivity,param,group,nsvars,sparse=False,perbc=None):
        self.connectivity=connectivity
        self.coords=coordinates
        self.ndim=3
        self.nnodes=coordinates.shape[0]
        self.ndofs=self.ndim*self.nnodes
        self.param=param
        self.group=group
        self.elements=self.generate_elements()
        self.nelements=len(self.elements)
        self.sparse=sparse
        self.nsvars=nsvars
        self.svars=np.zeros((len(self.elements),nsvars))
        self.perbc=perbc
        self.nperbc=0

        if self.perbc!=None:
            self.nperbc=self.ndim*len(self.perbc)
            self.jacperbc_Klu=self.get_jacperbc_matrices()
        self.Uglobal=np.zeros(( (self.ndofs+self.nperbc)//self.ndim , self.ndim ) )
    
    def get_jacperbc_matrices(self):
        Klu=np.zeros((self.nperbc,self.ndofs))
        n=self.ndim
        for i in range(self.nperbc//self.ndim):
            j=self.perbc[i][0]
            Klu[n*i:n*(i+1),n*j:n*(j+1)] = np.eye(self.ndim)
            j=self.perbc[i][1]
            Klu[n*i:n*(i+1),n*j:n*(j+1)] =-np.eye(self.ndim)
        return Klu
                
    def generate_elements(self):
        elements=np.array([lattice_element(self.connectivity[i],self.coords[self.connectivity[i]],i,self.param[self.group[i]]) 
                           for i in range(self.connectivity.shape[0])])
        return elements
    
    def assemble_global_jac_rhs(self,dUglobal,svars,BCs,ZeroDC=True):
        global_svars=np.zeros((self.nelements,self.nsvars))
        global_rhs=self.initialize_matrix(1,self.ndofs+self.nperbc)
        global_jac=self.initialize_matrix(self.ndofs+self.nperbc,self.ndofs+self.nperbc)
        ndim=self.ndim
        for el in self.elements:
            dUelement=dUglobal[el.nodeA]-dUglobal[el.nodeB]
            svarst_elem=svars[el.id]
            dforcetdt, jactdt, global_svars[el.id] = el.elements_jac_rhs(dUelement,svarst_elem)
            #rhs
            if np.linalg.norm(dforcetdt) !=0:
                global_rhs[0,ndim*el.nodeA:(ndim*(el.nodeA+1))] +=  dforcetdt
                global_rhs[0,ndim*el.nodeB:(ndim*(el.nodeB+1))] += -dforcetdt
            #jac
            global_jac[ndim*el.nodeA:ndim*(el.nodeA+1),ndim*el.nodeA:ndim*(el.nodeA+1)] +=  jactdt
            global_jac[ndim*el.nodeA:ndim*(el.nodeA+1),ndim*el.nodeB:ndim*(el.nodeB+1)] +=  -jactdt
            global_jac[ndim*el.nodeB:ndim*(el.nodeB+1),ndim*el.nodeA:ndim*(el.nodeA+1)] +=  -jactdt
            global_jac[ndim*el.nodeB:ndim*(el.nodeB+1),ndim*el.nodeB:ndim*(el.nodeB+1)] +=  jactdt
         
        #set perjac&rhs
        if self.perbc!=None:
            global_jac[:self.ndofs,-self.nperbc:]=self.jacperbc_Klu.T
            global_jac[-self.nperbc:,:self.ndofs]=self.jacperbc_Klu
            global_rhs[0,self.ndofs:]+=self.jacperbc_Klu @ dUglobal.flatten()[:self.ndofs]
            global_rhs[0,:self.ndofs]+=self.jacperbc_Klu.T @ dUglobal.flatten()[-self.nperbc:]
        
        #set BCs
        global_jac, global_rhs = self.set_BCs(global_jac, global_rhs,BCs,ZeroDC)
        return global_jac,global_rhs,global_svars 
    
    def set_BCs(self,gjac,grhs,BCs,ZeroDC=True):
        flag=1.
        for bc in BCs:
            if bc[2]=="DC":
                if ZeroDC==True: flag=0.
                grhs[0,bc[0]]=-bc[1]*flag
                gjac[bc[0],:]=0
                gjac[bc[0],bc[0]]=1.
            elif bc[2]=="NM":
                grhs[0,bc[0]]+=-bc[1]
            elif bc[2]=="PR":
                Fl=np.zeros(self.nperbc)
                for i in range(self.nperbc//self.ndim):
                    DFij=np.array(bc[1])
                    iB=self.perbc[i][0];iA=self.perbc[i][1]
                    DX=np.array(self.coords[iB]-self.coords[iA]).T
                    Fl[self.ndim*i:self.ndim*(i+1)]=DFij@DX
                grhs[0,-self.nperbc:]+=-Fl
        return gjac, grhs 
        
    def initialize_matrix(self,n,m):
        if self.sparse:
            return sp.csr_matrix((n,m))
        else:
            return np.zeros((n,m))
    
    def get_avg_stress(self):
        if self.perbc==None:
            return np.zeros((self.ndim,self.ndim))
        else:
            sigmaij=0
            for i in range(self.nperbc//self.ndim):
                ti=self.Uglobal[self.ndofs//self.ndim+i]
                iB=self.perbc[i][1]
                iA=self.perbc[i][0]
                xi=self.coords[iB]-self.coords[iA]
#                 print(xi)
                sigmaij+=np.tensordot(ti,xi,axes=0)#*l
            return sigmaij


#PERFORM INCREMENT

from scipy import optimize
import matplotlib.pyplot as plt

class solver:
    
    def __init__(self,lattice):
#         self.gentol=1.e-5
        self.rhstol=5.e-4
        self.dutol=5.e-4
        self.maxiter=2000
        self.lattice=lattice
    
    def solve(self,BCs,svarsM,add_svarsM,frc_svarsM):
        DU,svars,success,niter=self.do_increment(BCs)
        if success==True:
            self.lattice.Uglobal+=DU
            self.lattice.svars=svars.copy()
            svarsM[:6] = Tensor_to_Voigt(self.lattice.get_avg_stress())
            svarsM[12:12+nbars] = self.lattice.svars[:,0] # micro-stresses
            svarsM[12+nbars:12+2*nbars] = self.lattice.svars[:,4] # micro-strain
            svarsM[12+2*nbars:12+3*nbars] = self.lattice.svars[:,2] # micro additional-z
            svarsM[12+3*nbars:-3] = self.lattice.svars[:,7] # lengths/elongations
            svarsM[-3] = np.sum(self.lattice.svars[:,5]) # total energy
            svarsM[-2] = np.sum(self.lattice.svars[:,6]) # total dissipation rate 
            add_svarsM = self.lattice.Uglobal[:self.lattice.ndofs//self.lattice.ndim].copy()
            frc_svarsM = self.lattice.svars[:,-3:]
        return success,svarsM,add_svarsM,frc_svarsM,niter
    
    def do_increment(self,BCs):
        success=True
        niter=0
        
        #k indicates increments, i iterations
        DU_k1i1=np.zeros(self.lattice.ndofs+self.lattice.nperbc)
        DU_k1i=np.zeros(self.lattice.ndofs+self.lattice.nperbc)
        svars_k1i1=self.lattice.svars.copy()
        svars_k1i=svars_k1i1.copy()
        gjac_k1i1,grhs_k1i1,svars_k1i1=self.lattice.assemble_global_jac_rhs(
                                DU_k1i.reshape(
                                    (self.lattice.ndofs+self.lattice.nperbc)//self.lattice.ndim,
                                    self.lattice.ndim),
                                svars_k1i, BCs,ZeroDC=False)
        rhsnormki0=1
        #d indicates iterations, D increment
        dDU_k1i1 = scsolve(gjac_k1i1, grhs_k1i1.squeeze(),check_finite=False)
        DU_k1i1-=dDU_k1i1
        while True:
            niter+=1
            DU_k1i=DU_k1i1.copy()
            grhs_k1i=grhs_k1i1.copy()
            gjac_k1i1,grhs_k1i1,svars_k1i1=self.lattice.assemble_global_jac_rhs(
                                DU_k1i.reshape(
                                    (self.lattice.ndofs+self.lattice.nperbc)//self.lattice.ndim,
                                    self.lattice.ndim),
                                svars_k1i, BCs)
            
            rhsnormk1=np.linalg.norm(grhs_k1i1)
            dDU_k1i1 = scsolve(gjac_k1i1, grhs_k1i1.squeeze(),check_finite=False)
            DU_k1i1-=dDU_k1i1
            
            if np.linalg.norm(dDU_k1i1)<=self.dutol and rhsnormk1<=self.rhstol*rhsnormki0:
                break
            elif np.linalg.norm(dDU_k1i1)>self.dutol or rhsnormk1>self.rhstol*rhsnormki0:
                print("Residuals:",np.linalg.norm(dDU_k1i1),rhsnormk1)
                if niter>self.maxiter:
                    print("Maximum iterations reached.")
                    success=False
                    break
        print(niter)
        return DU_k1i1.reshape((self.lattice.ndofs+self.lattice.nperbc)//self.lattice.ndim,
                                self.lattice.ndim),svars_k1i1,success,niter    


def Tensor_to_Voigt(tensor):
    '''vector=[a11,a22,a33,a23,a32,a13,a31,a12,a21]'''
    vector=np.asarray([tensor[0,0],tensor[1,1],tensor[2,2],
                       tensor[1,2],tensor[0,2],tensor[0,1]],
                       dtype=np.float64)
    return vector

# ANALYSIS
cE = 8.96; cD = 9.0; A = np.pi*(1e-2)**2; cP=1000
Lcell= zmax/(nz-1)
param=[[1.,1./3.,0.01,Lcell**2],
       [1.,1./3.,0.01,Lcell**2/2.],
       [1.,1./3.,0.01,Lcell**2/4.]]
# print(param[:][3])
coorM[:,0]=coorM[:,0]-xmax/2
coorM[:,1]=coorM[:,1]-ymax/2
mylattice=lattice(coorM,conneM,param,groupM,nsvars=11,sparse=False,perbc=None)
nparticles = mylattice.ndofs//mylattice.ndim
nbars = mylattice.elements.shape[0]
nsvars = 4*nbars+2*6+1+1+1

ini_lattice_coords = mylattice.coords

steps = 2 #3
Umax = 5. #50. (assume it is in cm)

#do not change
u = np.linspace(0,Umax,steps)
print(u)
U=u;
for i in range(steps-1):
    U[i] = u[i+1]-u[i]
    
U[-1]=0
print(U)

svarsGP = np.zeros((steps,nsvars))
add_svarsGP = np.zeros((steps,ini_lattice_coords.shape[0],3))
frc_svarsGP = np.zeros((steps,nbars,3))
niter = np.zeros(steps)
for s in range(steps):
    print('STEP : ', s+1)
    DCBC=[]
    for i in range(ini_lattice_coords.shape[0]):
        if ini_lattice_coords[i,2]==0.:
            DCBC.append([3*i+0,0.,"DC"])
            DCBC.append([3*i+1,0.,"DC"])
            DCBC.append([3*i+2,0.,"DC"])
        if ini_lattice_coords[i,1]==-ymax/2:
            z = add_svarsGP[s,i,2]
            z0 = ini_lattice_coords[i,2]
            z+=z0
            uy = u[s]*(z/zmax)
            if s==steps-1: uy=0
#             print(uy)
            DCBC.append([3*i+1,uy,"DC"])
            
    slv=solver(mylattice);
    res,svarsGP[s],add_svarsGP[s],frc_svarsGP[s],niter[s]=slv.solve(DCBC,svarsGP[s],add_svarsGP[s],frc_svarsGP[s])
    if s!=steps-1:svarsGP[s+1]=svarsGP[s];add_svarsGP[s+1]=add_svarsGP[s];frc_svarsGP[s+1]=frc_svarsGP[s] 

# %matplotlib notebook
# plot_sol(mylattice.connectivity,mylattice.coords,mylattice.Uglobal[:mylattice.ndofs//mylattice.ndim],show_old=True,plot3D=True)
print(svarsGP[:,-3],svarsGP[:,-2])
        
outputs = [svarsGP,add_svarsGP,frc_svarsGP,nparticles,nbars,nsvars,niter,el]
# Out:
# [0. 5.]
# [5. 0.]
# STEP :  1
# Residuals: 0.5733419086000285 0.2661492274307225
# Residuals: 0.310689834182826 0.1069664475830452
# Residuals: 0.19896636598825387 0.06695702772918494
# Residuals: 0.14668629989210952 0.0558636646557495
# Residuals: 0.11848896208066817 0.05049078637342122
# Residuals: 0.10200849100735102 0.04689666454632889
# Residuals: 0.08984363985127593 0.04291827655400527
# Residuals: 0.08268281510889226 0.041213249620584286
# Residuals: 0.07700773272847686 0.039220077221275296
# Residuals: 0.07364791053602641 0.038421703371224844
# Residuals: 0.07093242216299406 0.03746943876958514
# Residuals: 0.06896630731783002 0.036772516385629034
# Residuals: 0.06723668075533025 0.036029106737712875
# Residuals: 0.06573613781603739 0.035327218089571635
# Residuals: 0.06432436494145674 0.03462269410483278
# Residuals: 0.06302428052277083 0.03395402417847884
# Residuals: 0.061771907606666086 0.033292869450992864
# Residuals: 0.06055377328920266 0.03264211300085602
# Residuals: 0.059363619920086916 0.0320029789160115
# Residuals: 0.0581984738990743 0.031375874512592244
# Residuals: 0.05705684831379759 0.030760847285980667
# Residuals: 0.055937866566750635 0.03015778841120482
# Residuals: 0.05484095842790415 0.029566504987242524
# Residuals: 0.053765591067786514 0.02898679568311663
# Residuals: 0.0527113960404144 0.028418426577626752
# Residuals: 0.05167791231963317 0.027861191327338927
# Residuals: 0.05066460873405303 0.02731490417315669
# Residuals: 0.04967113010783944 0.026779331219030648
# Residuals: 0.04869719641799884 0.02625424426704641
# Residuals: 0.04774236428486655 0.025739453111169458
# Residuals: 0.04680625109270142 0.025234756359093703
# Residuals: 0.045888479545114616 0.0247399566660947
# Residuals: 0.044988704079803425 0.024254858955424067
# Residuals: 0.04410657169563867 0.023779272991144833
# Residuals: 0.04324173634628061 0.023313012266493984
# Residuals: 0.04239385879577479 0.022855893931234536
# Residuals: 0.041562606478917484 0.02240773872026743
# Residuals: 0.04074765336583547 0.02196837088352796
# Residuals: 0.039948679830336724 0.021537618117178733
# Residuals: 0.039165372521693165 0.021115311496096106
# Residuals: 0.03839742423957614 0.020701285407648776
# Residuals: 0.03764453381193651 0.020295377486750307
# Residuals: 0.0369064059756484 0.01989742855217222
# Residuals: 0.03618275125977307 0.01950728254409868
# Residuals: 0.035473285871322646 0.019124786462900504
# Residuals: 0.03477773158342797 0.018749790309109657
# Residuals: 0.03409581562582049 0.018382147024570458
# Residuals: 0.033427270577552876 0.01802171243474689
# Residuals: 0.03277183426189299 0.01766834519216161
# Residuals: 0.03212924964333283 0.017321906720947397
# Residuals: 0.03149926472665521 0.016982261162486755
# Residuals: 0.03088163245801347 0.016649275322120714
# Residuals: 0.03027611062796881 0.016322818616902806
# Residuals: 0.02968246177644956 0.01600276302438102
# Residuals: 0.02910045309958647 0.015688983032382673
# Residuals: 0.028529856358384714 0.01538135558978852
# Residuals: 0.02797044778919259 0.01507976005826997
# Residuals: 0.027422008015932742 0.014784078164976448
# Residuals: 0.026884321964059214 0.01449419395614804
# Residuals: 0.02635717877620156 0.014209993751642093
# Residuals: 0.025840371729471272 0.013931366100348697
# Residuals: 0.025333698154385735 0.013658201736482842
# Residuals: 0.02483695935538696 0.01339039353673234
# Residuals: 0.024349960532916846 0.013127836478247638
# Residuals: 0.023872510707023453 0.012870427597456284
# Residuals: 0.0234044226424648 0.012618065949682462
# Residuals: 0.022945512775281226 0.012370652569560641
# Residuals: 0.022495601140810034 0.012128090432225671
# Residuals: 0.022054511303110185 0.011890284415261671
# Residuals: 0.02162207028577008 0.011657141261400723
# Residuals: 0.021198108504073897 0.011428569541949055
# Residuals: 0.020782459698496725 0.011204479620934142
# Residuals: 0.02037496086950353 0.01098478361995213
# Residuals: 0.01997545221363007 0.01076939538370565
# Residuals: 0.019583777060815856 0.010558230446217804
# Residuals: 0.019199781812961433 0.010351205997707173
# Residuals: 0.01882331588369421 0.010148240852113976
# Residuals: 0.018454231639316004 0.009949255415262313
# Residuals: 0.018092384340906455 0.009754171653646842
# Residuals: 0.017737632087564792 0.009562913063830778
# Residuals: 0.01738983576075911 0.00937540464244501
# Residuals: 0.017048858969773494 0.009191572856774945
# Residuals: 0.01671456799822022 0.009011345615923762
# Residuals: 0.01638683175160019 0.008834652242541648
# Residuals: 0.016065521705895 0.008661423445109706
# Residuals: 0.01575051185716479 0.008491591290765974
# Residuals: 0.015441678672135492 0.008325089178665514
# Residuals: 0.015138901039754045 0.008161851813862059
# Residuals: 0.014842060223694147 0.008001815181702556
# Residuals: 0.014551039815793821 0.007844916522723752
# Residuals: 0.014265725690401698 0.007691094308039328
# Residuals: 0.013986005959624511 0.007540288215212477
# Residuals: 0.013711770929451373 0.00739243910459886
# Residuals: 0.013442913056733391 0.007247488996154709
# Residuals: 0.013179326907010468 0.007105381046700355
# Residuals: 0.012920909113165 0.006966059527628173
# Residuals: 0.012667558334885306 0.006829469803048737
# Residuals: 0.012419175218925755 0.006695558308363781
# Residuals: 0.012175662360141861 0.0065642725292616114
# Residuals: 0.011936924263295057 0.006435560981123076
# Residuals: 0.011702867305603961 0.006309373188831218
# Residuals: 0.011473399700024658 0.006185659666977123
# Residuals: 0.011248431459260357 0.006064371900454462
# Residuals: 0.011027874360472582 0.00594546232543326
# Residuals: 0.010811641910681541 0.005828884310706976
# Residuals: 0.010599649312848165 0.005714592139407589
# Residuals: 0.01039181343261935 0.005602540991075961
# Residuals: 0.010188052765729325 0.005492686924084916
# Residuals: 0.009988287406034111 0.0053849868584082946
# Residuals: 0.009792439014176953 0.005279398558726433
# Residuals: 0.009600430786867 0.005175880617863023
# Residuals: 0.009412187426759385 0.005074392440547077
# Residuals: 0.009227635112928992 0.004974894227493049
# Residuals: 0.009046701471919502 0.00487734695979373
# Residuals: 0.008869315549361986 0.004781712383619201
# Residuals: 0.008695407782149125 0.004687952995213716
# Residuals: 0.008524909971157154 0.00459603202619024
# Residuals: 0.008357755254499917 0.004505913429109321
# Residuals: 0.008193878081307351 0.00441756186334478
# Residuals: 0.008033214186021391 0.004330942681223826
# Residuals: 0.007875700563193385 0.0042460219144397834
# Residuals: 0.007721275442774851 0.00416276626073092
# Residuals: 0.007569878265894215 0.00408114307082184
# Residuals: 0.007421449661110666 0.004001120335618025
# Residuals: 0.007275931421127942 0.003922666673654679
# Residuals: 0.007133266479968586 0.003845751318789925
# Residuals: 0.006993398890597332 0.003770344108139529
# Residuals: 0.006856273802979599 0.0036964154702481856
# Residuals: 0.006721837442572253 0.0036239364134933597
# Residuals: 0.006590037089233179 0.0035528785147157377
# Residuals: 0.006460821056547649 0.003483213908072364
# Residuals: 0.0063341386715630435 0.0034149152741100347
# Residuals: 0.006209940254912898 0.0033479558290502526
# Residuals: 0.0060881771013346795 0.0032823093142870827
# Residuals: 0.005968801460573796 0.003217949986089226
# Residuals: 0.005851766518652144 0.0031548526055047506
# Residuals: 0.00573702637951481 0.003092992428462875
# Residuals: 0.005624536047028942 0.003032345196070788
# Residuals: 0.005514251407337614 0.0029728871250995857
# Residuals: 0.005406129211563505 0.0029145948986591644
# Residuals: 0.005300127058844715 0.0028574456570526906
# Residuals: 0.005196203379710156 0.00280141698881271
# Residuals: 0.005094317419776132 0.002746486921912696
# Residuals: 0.004994429223762539 0.0026926339151496477
# Residuals: 0.004896499619829304 0.0026398368496975797
# Residuals: 0.0048004902042105835 0.0025880750208249347
# Residuals: 0.004706363326154949 0.002537328129775233
# Residuals: 0.00461408207316056 0.002487576275807079
# Residuals: 0.004523610256500086 0.0024387999483892497
# Residuals: 0.004434912397031049 0.0023909800195503444
# Residuals: 0.004347953711279235 0.002344097736377
# Residuals: 0.004262700097797649 0.0022981347136601265
# Residuals: 0.004179118123797741 0.002253072926685252
# Residuals: 0.004097175012035913 0.0022088947041627974
# Residuals: 0.0040168386279575054 0.002165582721300162
# Residuals: 0.0039380774670981665 0.0021231199930057247
# Residuals: 0.0038608606427279427 0.002081489867229379
# Residuals: 0.0037851578737387397 0.002040676018431553
# Residuals: 0.003710939472770615 0.002000662441181079
# Residuals: 0.003638176334568292 0.001961433443879284
# Residuals: 0.003566839924568612 0.001922973642605612
# Residuals: 0.003496902267708502 0.0018852679550850412
# Residuals: 0.0034283359374559356 0.0018483015947735521
# Residuals: 0.003361114045053375 0.0018120600650592083
# Residuals: 0.0032952102289745145 0.0017765291535772598
# Residuals: 0.003230598644585865 0.0017416949266371514
# Residuals: 0.0031672539540103413 0.0017075437237574567
# Residuals: 0.003105151316192928 0.0016740621523098935
# Residuals: 0.003044266377159487 0.0016412370822661464
# Residuals: 0.0029845752604621086 0.0016090556410499651
# Residuals: 0.0029260545578198246 0.0015775052084882697
# Residuals: 0.0028686813199381095 0.001546573411862317
# Residuals: 0.0028124330475077556 0.0015162481210559318
# Residuals: 0.0027572876823821683 0.0014865174437979293
# Residuals: 0.002703223598927972 0.0014573697209993876
# Residuals: 0.00265021959554432 0.0014287935221808106
# Residuals: 0.002598254886347926 0.0014007776409897931
# Residuals: 0.002547309093020906 0.0013733110908062428
# Residuals: 0.0024973622368198462 0.0013463831004338908
# Residuals: 0.002448394730743622 0.0013199831098762269
# Residuals: 0.0024003873718487704 0.001294100766196241
# Residuals: 0.002353321333719632 0.001268725919455235
# Residuals: 0.002307178159086799 0.0012438486187328723
# Residuals: 0.002261939752586836 0.001219459108224791
# Residuals: 0.0022175883736688115 0.0011955478234169216
# Residuals: 0.0021741066296349213 0.0011721053873352334
# Residuals: 0.002131477468820404 0.0011491226068673433
# Residuals: 0.002089684173907009 0.001126590469157909
# Residuals: 0.0020487103553674803 0.0011045001380751266
# Residuals: 0.0020085399450387132 0.0010828429507435352
# Residuals: 0.001969157189818385 0.001061610414148612
# Residuals: 0.0019305466454881048 0.0010407942018053143
# Residuals: 0.0018926931706575206 0.0010203861504933
# Residuals: 0.0018555819208277392 0.0010003782570553253
# Residuals: 0.0018191983425677116 0.0009807626752582918
# Residuals: 0.0017835281678070364 0.0009615317127170143
# Residuals: 0.0017485574082417479 0.000942677827878274
# Residuals: 0.0017142723498481764 0.0009241936270612968
# Residuals: 0.001680659547505641 0.0009060718615598012
# Residuals: 0.0016477058197236143 0.0008883054247996364
# Residuals: 0.0016153982434712313 0.0008708873495502966
# Residuals: 0.001583724149110342 0.0008538108051940043
# Residuals: 0.0015526711154281378 0.0008370690950465701
# Residuals: 0.0015222269647642216 0.0008206556537316135
# Residuals: 0.0014923797582359405 0.0008045640446056158
# Residuals: 0.0014631177910557076 0.0007887879572334747
# Residuals: 0.0014344295879418316 0.0007733212049142879
# Residuals: 0.0014063038986198836 0.0007581577222548871
# Residuals: 0.0013787296934073396 0.0007432915627914814
# Residuals: 0.0013516961588901353 0.000728716896658026
# Residuals: 0.0013251926936830374 0.0007144280082990296
# Residuals: 0.0012992089042696484 0.000700419294228314
# Residuals: 0.0012737346009292143 0.0006866852608330592
# Residuals: 0.0012487597937379186 0.0006732205222175131
# Residuals: 0.0012242746886540889 0.0006600197980925802
# Residuals: 0.0012002696836764712 0.0006470779117030352
# Residuals: 0.0011767353650764417 0.0006343897877996505
# Residuals: 0.0011536625037097284 0.0006219504506472458
# Residuals: 0.001131042051395856 0.0006097550220748048
# Residuals: 0.0011088651373693174 0.0005977987195609762
# Residuals: 0.0010871230648007916 0.0005860768543601751
# Residuals: 0.0010658073073873129 0.0005745848296619008
# Residuals: 0.0010449095060088573 0.0005633181387902886
# Residuals: 0.001024421465448409 0.0005522723634349237
# Residuals: 0.0010043351511796258 0.0005414431719192366
# Residuals: 0.0009846426862173312 0.0005308263175014135
# Residuals: 0.0009653363480268615 0.0005204176367091806
# Residuals: 0.0009464085654944554 0.0005102130477070338
# Residuals: 0.0009278519159606815 0.0005002085486953757
# Residuals: 0.0009096591223082614 0.0004904002163411895
# Residuals: 0.0008918230501080752 0.0004807842042395712
# Residuals: 0.0008743367048214767 0.0004713567414055702
# Residuals: 0.0008571932290585899 0.0004621141307946957
# Residuals: 0.000840385899886845 0.00045305274785400763
# Residuals: 0.0008239081261982303 0.0004441690390996499
# Residuals: 0.000807753446120159 0.00043545952072408345
# Residuals: 0.0007919155244836128 0.00042692077723072104
# Residuals: 0.0007763881503393782 0.0004185494600922988
# Residuals: 0.000761165234520626 0.00041034228643933016
# Residuals: 0.0007462408072569218 0.0004022960377723041
# Residuals: 0.0007316090158330141 0.00039440755869957987
# Residuals: 0.0007172641222897581 0.0003866737557000884
# Residuals: 0.0007032005011789611 0.0003790915959099063
# Residuals: 0.0006894126373556738 0.00037165810593288445
# Residuals: 0.0006758951238137361 0.00036437037067466374
# Residuals: 0.0006626426595667854 0.000357225532200505
# Residuals: 0.0006496500475704939 0.00035022078861262577
# Residuals: 0.0006369121926836486 0.0003433533929527315
# Residuals: 0.0006244240996687203 0.00033662065212427205
# Residuals: 0.0006121808712340014 0.00033001992583708807
# Residuals: 0.0006001777061136361 0.00032354862557101177
# Residuals: 0.0005884098971844001 0.00031720421356111364
# Residuals: 0.0005768728296186618 0.0003109842018028645
# Residuals: 0.0005655619790765618 0.0003048861510758525
# Residuals: 0.0005544729099312439 0.0002989076699874889
# Residuals: 0.0005436012735270891 0.0002930464140356973
# Residuals: 0.0005329428064771634 0.00028730008468858876
# Residuals: 0.0005224933289909131 0.00028166642848351296
# Residuals: 0.0005122487432344768 0.0002761432361438379
# Residuals: 0.0005022050317224154 0.0002707283417113549
# 261
# STEP :  2
# 1
# [32.7147683 32.7147683] [0.59269063 0.        ]

# %%
w_in_file = './SINGLESTEP_PUSHOVER_L'+str(nx-1)+'x'+str(ny-1)+'x'+str(nz-1)+'_V10x10x30*'
with open(w_in_file, 'wb') as f_obj:
     pickle.dump(outputs, f_obj)

# %%
# plot_sol(mylattice.connectivity,mylattice.coords,mylattice.Uglobal[:mylattice.ndofs//mylattice.ndim],show_old=True,plot3D=True)

# %%
# fl1 = 'PUSHOVER_L10x10x30_V10x10x30'
# with open(fl1, 'rb') as f_obj:
#     svarsGP,add_svarsGP,frc_svarsGP,nparticles,nbars,nsvars,niter,el = pickle.load(f_obj)

# %%
# svarsGP,add_svarsGP,nparticles,nbars,nsvars,niter,nel = output


E_m=svarsGP[:-1,-3] #total energy (elastic)
D_m=svarsGP[:-1,-2] #total dissipation rate
U_m=add_svarsGP[:-1] #nodal displacements
F_m=frc_svarsGP[:-1] #forces at the bars

# %%
# Find ID bars at the ground floor
barsID = []
for i in range(conneM.shape[0]):
    cons=conneM[i]
    p1 = coorM[cons[0]]; p2 = coorM[cons[1]]
    if p1[2]<=zmax/(nz-1):
        barsID.append([i])

# %%
# Bars forces at the ground floor
frc_svarsGP[:-1,barsID]

# Find y-projection of the bars' forces
e2 = np.array([0,1,0])
fy = np.dot(frc_svarsGP[:-1,barsID],e2)

# Compute the sum
Fy = np.sum(fy,axis=1)

# %% [markdown]
# ###  Nonlinear Analysis Method for Performance Based Seismic Design : N2 Method

# %% [markdown]
# #### Step 1 :  Pushover Analysis

# %% [markdown]
# #####  (a) Assume a linear displacement shape, ϕ

# %%
# Linear lateral displacement shape, ϕ
ϕT=[]
for i in range(1,nz):
    u=Umax*i/(nz-1)
    ϕT.append(u)
#print("Lateral displacement shape, ϕT : ", ϕT)

# Normalized linear lateral displacement shape, ϕn (normalized such that the displacement at the top is equal to 1)
ϕnT=[]
for i in range(1,nz):
    u=i/(nz-1)
    ϕnT.append(u)
#print("Normalized lateral displacement shape, ϕnT : ", ϕnT)

# %% [markdown]
# #####  (b) Determine vertical distribution of lateral forces, P

# %%
# Parameters
m = 80 #lumped floor mass, in tonnes #assuming floor mass is constant across floors
M = np.diag(m * np.ones(nz-1)) #mass matrix
#print("mass matrix, M: ", M)
p=1 # factor to control magnitude of lateral loads

# Lateral force pattern, P 
P=p*np.matmul((M*9.81), np.transpose(ϕnT)) #*9.81 N/kg so, unit of P is kN
#print("Lateral force pattern, P : ", P)

# Normalized lateral force pattern, Pn (normalized such that the displacement at the top is equal to 1)
Pn=P/P[nz-2]
#print("Normalized lateral force pattern, Pn : ", Pn)

# %% [markdown]
# #####  (c) Determine base shear (V ) - top displacement (Dt) relationship

# %%
# Base shear - top displacement relationship

s=steps-1

# Displacement,u
u = np.zeros(s+1)
for i in range(s):
    u[1+i]=(Umax/s)*(i+1)
#   u.append(delta_u)
#print("Top displacement, Dt : ", u, "in cm")

# Force, Fy
Vy = np.zeros(s+1)
for i in range(s):
    Vy[1+i]=Fy[i][0]*1000
#   V.append(delta_F*1000) #Force is x 10**3 to plot in kN 
print("Base shear, V : ", V, "in kN")

# Extension past last point
#x0=np.linspace(u[-1],(u[-1]+5))
#y0=(V[-1])*np.ones(50)

# Plot curve
plt.rcParams["figure.figsize"] = (6,5)
plt.plot(u,Vy,color='k', alpha = 1, marker='o', linestyle='-',linewidth=0.8, markersize=6)
#plt.plot(x0,y0,color='k', linestyle='--',linewidth=0.8)
plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.title('Force-displacement curve of MDOF system')
plt.ylabel('$Base$ $shear, V (kN) $');plt.xlabel('$Top$ $displacement, D_t$ $(cm)$'); plt.show()
# Out:
# Base shear, V :  1000 in kN

# %%
file = './SINGLELOAD_PUSHOVER_Macro-3D_L15x15x15'
with open(file, 'rb') as f_obj:
    data = pickle.load(f_obj)
N1=15;N2=N1;N3=15.
N=N1*N2*N3
V=10*10*10
usol,stress,svars,IC = data
energy= svars[:,:,-3]
dissipation= svars[:,:,-2]
usol=np.reshape(usol,(usol.shape[0],-1,3))
U0x=usol[:,:,0]
U0y=usol[:,:,1]
U0z=usol[:,:,2]
Uy=np.zeros(U0y.shape[0])
for i in range(U0y.shape[0]):
    Uy[i] = np.amax(U0y[i])
    
E0=np.sum(energy,1)
D0=np.sum(dissipation,1)
IC_u = IC[:,:,-24:]
IC_f = IC[:,:,:-24]
IC_u = IC_u.reshape(IC_u.shape[0],IC_u.shape[1],IC_u.shape[2]//3,3)
frc_svarsGP = IC_f[:,:N1*N2*6,:]
E0202030=E0*V/(N*6)
D0202030=D0*V/(N*6)
E0,D0
barnv = np.array([[-1.        ,  0.        ,  0.        ],
       [ 0.        , -1.        ,  0.        ],
       [-0.70710678, -0.70710678,  0.        ],
       [-1.        ,  0.        ,  0.        ],
       [ 0.        , -1.        ,  0.        ],
       [ 0.70710678, -0.70710678,  0.        ],
       [-1.        ,  0.        ,  0.        ],
       [ 0.        , -1.        ,  0.        ],
       [-0.70710678, -0.70710678,  0.        ],
       [ 0.        ,  0.        ,  1.        ],
       [ 0.        , -0.70710678,  0.70710678],
       [-0.70710678,  0.        ,  0.70710678],
       [-1.        ,  0.        ,  0.        ],
       [ 0.        ,  0.        ,  1.        ],
       [ 0.        ,  0.70710678,  0.70710678],
       [-0.70710678,  0.        ,  0.70710678],
       [ 0.        , -1.        ,  0.        ],
       [ 0.70710678, -0.70710678,  0.        ],
       [ 0.        ,  0.        ,  1.        ],
       [ 0.        , -0.70710678,  0.70710678],
       [ 0.70710678,  0.        ,  0.70710678],
       [ 0.        ,  0.        ,  1.        ],
       [ 0.        ,  0.70710678,  0.70710678],
       [ 0.70710678,  0.        ,  0.70710678]])

frc = np.zeros((frc_svarsGP.shape[0],N1*N2*6,24,3))
for t in range(frc_svarsGP.shape[0]):
    for b in range(N1*N2*6):
        for i in range(24):
            frc[t,b,i,:]=(frc_svarsGP[t,b,i]*(barnv[i]))
            
fy = np.zeros((frc_svarsGP.shape[0],N1*N2*6,24))
for t in range(frc_svarsGP.shape[0]):
    for b in range(N1*N2*6):
        for i in range(24):
            fy[t,b,i]=np.dot(frc[t,b,i],np.array([0,1,0]))
            
Fy = np.sum(np.sum(fy,axis=2),axis=1)
Ry202030 = np.zeros(1+Fy.shape[0])
Ry202030[1:]=Fy
Sy202030 = np.zeros(1+Uy.shape[0])
Sy202030[1:]=Uy
# Ry

# %%
E0,E_m
# Out:
# (array([658.20851862]), array([32.7147683]))

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (3,3)
plt.plot(Sy202030,50*Ry202030,color='darkorange', alpha = 1, marker='o', linestyle='-',linewidth=1, markersize=6)
plt.plot(u,Vy,color='k', alpha = 1, marker='o', linestyle='--',linewidth=1, markersize=0)

# plt.plot(np.array(0,,Fy[0]*0*1000,color='k', alpha = 1, marker='o', linestyle='--',linewidth=1, markersize=6)
plt.grid(color='k', linestyle='--', linewidth=0.2)
plt.title('Force-displacement curve of MDOF system')
plt.ylabel('$Base$ $shear, V$');plt.xlabel('$Top$ $displacement, D_t$ $(m)$'); plt.show()

# %%
np.amax(Vy)/np.amax(Ry202030)
# Out:
# 30.915063515947306

# %% [markdown]
# CORRECT VALUES
#
# Top displacement, Dt :  [0, 1.75, 3.5, 5.25, 7.0, 8.75, 10.5, 12.25, 14.0, 15.75, 17.5, 19.25, 21.0, 22.75, 24.5, 26.25, 28.0, 29.75, 31.5, 33.25, 35.0] in cm
# Base shear, V :  [0, 2651.11012117666, 5474.303812401221, 8475.21863917693, 11659.600136592626, 15025.035534657449, 18431.330578837154, 22026.97883170895, 25661.762652152447, 29087.376346894933, 31887.003308291107, 34509.89412548675, 36896.02191902953, 38723.31707347358, 39994.94921034061, 40670.23335031657, 40877.63987063364, 40950.94492536998, 41079.92660904603, 41156.644742921104, 41382.12136109916] in kN

# %% [markdown]
# DO NOT USE
#
# with nx instead of nz
#
# Top displacement, Dt :  [0, 1.75, 3.5, 5.25, 7.0, 8.75, 10.5, 12.25, 14.0, 15.75, 17.5, 19.25, 21.0, 22.75, 24.5, 26.25, 28.0, 29.75, 31.5, 33.25, 35.0] in cm
# Base shear, V :  [0, 8291.572417826566, 17082.034965854327, 26386.405117290906, 36219.94744087349, 46577.89214449549, 57042.23179191049, 67916.36060241585, 79063.96029157189, 89924.09961649659, 99597.98849946039, 108906.71216259936, 117543.20603470966, 124441.65799821047, 129331.56035007397, 132492.2688047674, 134260.36681085452, 135285.34266187155, 136131.97551487197, 136801.52293000082, 137534.5514244618] in kN

# %% [markdown]
# #### Step 2 : Transformation of MDOF system to an equivalent SDOF system

# %% [markdown]
# ##### (a) Determine equivalent mass, m*

# %%
mass_eq = np.sum(np.matmul(M, np.transpose(ϕnT)))
print("m* =", mass_eq, "tonnes" ) # in tonnes
# Out:
# m* = 1240.0 tonnes

# %% [markdown]
# #####  (b) Transform MDOF quantities (Q) to SDOF quantities (Q*)

# %%
# Transformation factor, Γ
Γ= mass_eq/np.sum(np.matmul(M, np.square(np.transpose(ϕnT))))
print("Transformation factor, Γ :", Γ)

# Force,F* and displacement,D* of SDOF system
F_SDOF=V/Γ
D_SDOF=u/Γ

# Extension past last point
x1=np.linspace(D_SDOF[-1],(D_SDOF[-1]+5))
y1=(F_SDOF[-1])*np.ones(50)

# Plot SDOF curve
plt.rcParams["figure.figsize"] = (6,5)
fig, ax = plt.subplots(constrained_layout=True)
ax.plot(D_SDOF,F_SDOF,color='k', alpha = 1, marker='o', linestyle='-',linewidth=0.8, markersize=6, label='pushover curve')
#ax.plot(x1,y1,color='k', linestyle='--',linewidth=0.8)
ax.set_xlabel('$Top$ $displacement, D* (cm)$')
ax.set_ylabel('$Base$ $shear, V* (kN) $')
ax.set_title('Force-displacement curve')

#Add MDOF axis to plot (i.e. same curve, different scale)

def force_SDOF2MDOF(F_SDOF):
    return F_SDOF * Γ


def force_MDOF2SDOF(V):
    return V/Γ

def disp_SDOF2MDOF(D_SDOF):
    return D_SDOF * Γ


def disp_MDOF2SDOF(u):
    return u/Γ

secax = ax.secondary_xaxis('top', functions=(disp_SDOF2MDOF, disp_MDOF2SDOF))
secax.set_xlabel('$Top$ $displacement, D_t$ $(cm)$')
secax = ax.secondary_yaxis('right', functions=(force_SDOF2MDOF, force_MDOF2SDOF))
secax.set_ylabel('$Base$ $shear, F (kN)$')
plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.show()
# Out:
# Transformation factor, Γ : 1.4754098360655739

# %% [markdown]
# #####  (c) Determine an approximate elasto-plastic force – displacement relationship

# %% [markdown]
# ##### Note :  FEMA-356 bilinear curve checks (adopted as verifications in N2 method)

# %% [markdown]
# Based on FEMA-356, first you need to assume a point as yield pointing and then follow these steps:
# The bilinear curve is composed of elastic and post-elastic part.
#
# 1- The elastic part connects the origin to assumed yield point, but the elastic line and the real curve must intersect at 0.6Vy, where Vy is shear at yield point #check 1
#
# 2- connect yield point to the target displacement point, but consider that your assumed Vy must not exceed maximum shear capacity of building. #check 2
#
# 3- the area under your bi-linear curve and real curve must approximately match. if not, you can modify assumed yield point to get it. #check 3

# %%
# Trilinear idealization of the pushover curve

# 1 - Plot SDOF curve
plt.rcParams["figure.figsize"] = (6,5)
fig, ax = plt.subplots(constrained_layout=True)
ax.plot(D_SDOF,F_SDOF,color='k', alpha = 1, marker='o', linestyle='-',linewidth=0.8, markersize=6, label='pushover curve')
#ax.plot(x1,y1,color='k', linestyle='--',linewidth=0.8)
ax.set_xlabel('$Top$ $displacement, D*$ $(cm)$')
ax.set_ylabel('$Base$ $shear, V* (kN)$')
ax.set_title('Force-displacement curve')

# Add MDOF axis to plot (same curve, different scale)

def force_SDOF2MDOF(F_SDOF):
    return F_SDOF * Γ


def force_MDOF2SDOF(V):
    return V/Γ

def disp_SDOF2MDOF(D_SDOF):
    return D_SDOF * Γ


def disp_MDOF2SDOF(u):
    return u/Γ

secax1 = ax.secondary_xaxis('top', functions=(disp_SDOF2MDOF, disp_MDOF2SDOF))
secax1.set_xlabel('$Top$ $displacement, D_t$ $(cm)$')
secax2 = ax.secondary_yaxis('right', functions=(force_SDOF2MDOF, force_MDOF2SDOF))
secax2.set_ylabel('$Base$ $shear, F (kN)$' )

# 2 - Approximate trilinear curve functions

#elastic section
x2 = np.linspace(0,D_SDOF[12])
m2 = F_SDOF[11]/D_SDOF[11]
y2 = m2*x2
ax.plot(x2,y2,'c-',linewidth=2, label='stiffness, effective')

#post-elastic section - 1 
x3 = np.linspace(D_SDOF[11],(D_SDOF[15])) 
m3 = (F_SDOF[15]-F_SDOF[11])/(D_SDOF[15]-D_SDOF[11])
y3 = m3*x3+12500
ax.plot(x3,y3,'b-',linewidth=2, label='post-elastic, section 1 ')

#post-elastic section - 2
x4 = np.linspace(D_SDOF[13],(D_SDOF[-1]))
m4 = F_SDOF[-3]
y4 = m4*np.ones(50)
ax.plot(x4,y4,'b-',linewidth=2, label='stiffness, post-yielding')

# 3 - FEMA checks 

#check 1 
#x3=np.linspace(0,50)
#y3=2.64*np.ones(50)
#ax.plot(x3,y3,'r-',linewidth=2)

#check 2?
#check 3? calculate area under curves

# 4 - yield point (intersect of elastic and post-elastic section)

intersect_x_yield_1=[]
intersect_y_yield_1=[]

x_for_yield_1 = np.linspace(10,20,100000)
y2_for_yield = np.round(m2*x_for_yield_1)
y3_for_yield = np.round((m3*x_for_yield_1+12500))

for i in range(len(x_for_yield_1)):
    if np.any(y2_for_yield[i]==y3_for_yield[i]):
        intersect_x_yield_1.append(x_for_yield_1[i])
        intersect_y_yield_1.append(y2_for_yield[i])

ax.plot(intersect_x_yield_1,intersect_y_yield_1,color='r', alpha = 1, marker='o', linestyle='-',linewidth=0, markersize=5, label=("yield point"))

plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #####  (d) Determine strength Fy * , yield displacement Dy* , and period T*

# %%
print("Yield displacement, Dy* : ",intersect_x_yield_1[0],"cm")
print("Yield strength, Fy* :",intersect_y_yield_1[0], "kN")

T_elastic = 0.1*2*np.pi*np.sqrt((mass_eq*intersect_x_yield_1[0])/(intersect_y_yield_1[0]))
print("Elastic period, T* :",T_elastic, "in s")
# Out:
# Yield displacement, Dy* :  13.695136951369514 cm
# Yield strength, Fy* : 24552.0 kN
# Elastic period, T* : 0.5225531415221448 in s

# %% [markdown]
# ##### (e)  Determine capacity diagram (acceleration versus displacement)

# %%
S_ay = intersect_y_yield_1[0]/(mass_eq*9.81)
print("Acceleration at yield point, S_ay :",S_ay)

# Plot SDOF curve
plt.rcParams["figure.figsize"] = (6,5)
fig, ax = plt.subplots(constrained_layout=True)
ax.plot(D_SDOF,F_SDOF,color='k', alpha = 1, marker='o', linestyle='-',linewidth=0.8, markersize=6, label='pushover curve')
#ax.plot(x1,y1,color='k', linestyle='--',linewidth=0.8)
ax.set_xlabel('$Top$ $displacement, D*$ $(cm)$')
ax.set_ylabel('$Base$ $shear, V* (kN)$')
ax.set_title('Force-displacement curve')

# Add MDOF axis to plot (same curve, different scale)

def force_SDOF2MDOF(F_SDOF):
    return F_SDOF * Γ


def force_MDOF2SDOF(V):
    return V/Γ

def disp_SDOF2MDOF(D_SDOF):
    return D_SDOF * Γ


def disp_MDOF2SDOF(u):
    return u/Γ

ax.plot(x2,y2,'c-',linewidth=2, label='elastic section')
ax.plot(x3,y3,'b-',linewidth=2, label='post-elastic, section 1 ')
ax.plot(x4,y4,'b-',linewidth=2, label='post-elastic, section 2')
ax.plot(intersect_x_yield_1,intersect_y_yield_1,color='r', alpha = 1, marker='o', linestyle='-',linewidth=0, markersize=5, label=("yield point"))

# Add acceleration axis to plot (capacity diagram is same as trilinear curve, but with different axis)

def capacity(F_SDOF):
    return F_SDOF/(mass_eq*9.81)

def capacity_inverse(S_ay):
    return S_ay*mass_eq*9.81

secax1 = ax.secondary_xaxis('top', functions=(disp_SDOF2MDOF, disp_MDOF2SDOF))
secax1.set_xlabel('$Top$ $displacement, D_t$ $(cm)$')
secax2 = ax.secondary_yaxis('right', functions=(force_SDOF2MDOF, force_MDOF2SDOF))
secax2.set_ylabel('$Base$ $shear, F (kN)$' )
secax3 = ax.secondary_yaxis(-0.3, functions=(capacity, capacity_inverse))
secax3.set_ylabel('$S_a$ $(-) x g$', labelpad=10 )

plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.legend(loc='best')
plt.show
# Out:
# Acceleration at yield point, S_ay : 2.018348623853211
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Step 3 : Demand Spectra in AD Format

# %% [markdown]
# ##### (a) Determine elastic acceleration spectrum, Sae

# %%
# 1 - Data

#Ground Type A, Spectrum Type 1

S = 1.0 #soil factor
T_B = 0.15 #lower limit of the constant acceleration branch
T_C = 0.6 #upper limit of the constant acceleration branch
T_D = 3.0 #value defining the beginning of the constant displacement branch

a_g = 0.3 #design acceleration on rock (= 0.3 g), corresponds to value assigned for zone 5 in France
ζ = 0.05 #damping ratio
η = 1 #damping correction factor for damping ratio at 5%
μ = 0.70 #ductility factor defined as the ratio between the maximum displacement and the yield displacement

# 2 - Typical elastic acceleration spectrum, Sae

T_list = []
S_ae = []
S_de = []
S_a = []
S_d=[]

for T in np.linspace(0,T_B,500):
    T_list.append(T) #time
    Sae = a_g*S*(1+((T/T_B)*((2.5*η)-1))) # acceleration, elastic SDOF
    S_ae.append(Sae/a_g) #normalised elastic acceleration
    Sde = ((T**2)/(4*np.pi**2))*(Sae/a_g)*(9.81)*100 # displacement, elastic SDOF
    S_de.append(Sde)
    R_μ = ((μ-1)*(T/T_C))+1 # reduction factor
    S_a.append(Sae/a_g/R_μ) # acceleration, inelastic SDOF 
    Sd = (μ/R_μ)*Sde # displacement, inelastic SDOF
    S_d.append(Sd)
    
for T in np.linspace(T_B,T_C,500):
    T_list.append(T)
    Sae=2.5*a_g*S*η
    S_ae.append(Sae/a_g)
    Sde = ((T**2)/(4*np.pi**2))*(Sae/a_g)*(9.81)*100
    S_de.append(Sde)
    if T < T_C:
        R_μ = ((μ-1)*(T/T_C))+1
        S_a.append(Sae/a_g/R_μ)
        Sd = (μ/R_μ)*Sde
        S_d.append(Sd)
    else:
        R_μ = μ    
        S_a.append(Sae/a_g/R_μ)
        Sd = (μ/R_μ)*Sde
        S_d.append(Sd)

for T in np.linspace(T_C,T_D,500):
    T_list.append(T)
    Sae=2.5*a_g*S*η*(T_C/T)
    S_ae.append(Sae/a_g)
    Sde = ((T**2)/(4*np.pi**2))*(Sae/a_g)*(9.81)*100
    S_de.append(Sde)
    R_μ = μ    
    S_a.append(Sae/a_g/R_μ)
    Sd = (μ/R_μ)*Sde
    S_d.append(Sd)

for T in np.linspace(T_D,4,500):
    T_list.append(T)
    Sae=2.5*a_g*S*η*(T_C*T_D/T**2)
    S_ae.append(Sae/a_g)
    Sde = ((T**2)/(4*np.pi**2))*(Sae/a_g)*(9.81)*100
    S_de.append(Sde)
    R_μ = μ    
    S_a.append(Sae/a_g/R_μ)
    Sd = (μ/R_μ)*Sde
    S_d.append(Sd)

# radial line for T_B
y_T_B = S*(1+(2.5*η)-1)
x_T_B = ((T_B**2)/(4*np.pi**2))*(y_T_B)*(9.81)*100
m = y_T_B/x_T_B
rad_x_T_B=np.linspace(0,x_T_B)
rad_y_T_B= m*rad_x_T_B  

# radial line for T_C
y_T_C = 2.5*a_g*S*η
x_T_C = ((T_C**2)/(4*np.pi**2))*(y_T_C)*(9.81)*100
m = y_T_C/x_T_C
rad_x_T_C=np.linspace(0,22)
rad_y_T_C= m*rad_x_T_C  


# Plot a typical elastic acceleration (S_ae) spectrum

#plt.rcParams["figure.figsize"] = (6,5)
#plt.plot(T_list,S_ae,'k',linewidth=1)
#plt.grid(color='k', linestyle='--', linewidth=0.5)
#plt.title('Typical Elastic Acceleration Spectrum')
#plt.ylabel('$S_ae$ $(-) x g$');plt.xlabel('$T(s)$'); plt.show()

# %% [markdown]
# ##### (b) Determine elastic spectrum in AD format

# %%
# Plot a typical elastic acceleration (S_ae) and displacement (S_de) spectrum in AD format (i.e μ = 1.0 )

#plt.rcParams["figure.figsize"] = (6,5)
#plt.plot(S_de,S_ae,'k',linewidth=1)
#plt.plot(rad_x_T_B,rad_y_T_B,'b',linewidth=1)
#plt.plot(rad_x_T_C,rad_y_T_C,'b',linewidth=1)
#plt.grid(color='k', linestyle='--', linewidth=0.5)
#plt.title('Typical Elastic Spectrum in AD format')
#plt.ylabel('$S_ae$ $(-) x g $');plt.xlabel('$S_de$ $(cm)$'); plt.show()

# %% [markdown]
# ##### (c) Determine inelastic spectra for constant ductilities

# %%
# Plot a typical inelastic acceleration (S_a) and displacement (S_d) spectrum in AD format (μ = 1.5)

#plt.rcParams["figure.figsize"] = (6,5)
#plt.plot(S_d,S_a,'k',linewidth=1)
#plt.grid(color='k', linestyle='--', linewidth=0.5)
#plt.title('Typical Inelastic Spectrum in AD format')
#plt.ylabel('$S_a$ $(g)$');plt.xlabel('$S_d$ $(cm)$'); plt.show()

# %% [markdown]
# #### Step 4 : Seismic Demand for SDOF Model ( in Elastic Demand Spectrum (matches N2 paper) file)

# %%
# Testing the demand spectrum using test example data

design_a_g = 0.6 #peak ground acceleration to design for

#normalize with respect to peak ground acceleration designing for
S_ae_new = []
S_de_new = []
S_a_new = []
S_d_new = []

for Sae in S_ae:
    S_ae_new.append(Sae * design_a_g)
for Sde in S_de:
    S_de_new.append(Sde * design_a_g)
for Sa in S_a:
    S_a_new.append(Sa * design_a_g)
for Sd in S_d:
    S_d_new.append(Sd * design_a_g)   


#radial line for elastic period
y_T = 2.5*design_a_g*S*η
x_T = ((T_elastic**2)/(4*np.pi**2))*(y_T)*(9.81)*100
m = y_T/x_T
rad_x_T=S_de_new
rad_y_T= []
for i in rad_x_T:
    rad_y_T.append(m*i)

# global seismic demand 

# 1 - In the case of unlimited elastic behavior of the structure - seismic demand is represented by the intersection of the elastic demand spectrum and the line corresponding to the elastic period (T * = 0.79 s) of the equivalent SDOF system.
intersect_x_elastic = []
intersect_y_elastic = []

for i in range(len(S_de_new)):
    a1=np.round(rad_y_T,1)
    b1=np.round(S_ae_new,1)
    if np.any(b1[i]==a1[i]):
        intersect_x_elastic.append(np.round(S_de_new[i],1))
        intersect_y_elastic.append(b1[i])

print('Sde =', intersect_x_elastic[0], 'cm' )
print('Sae =', intersect_y_elastic[0], 'g')

# 2 - In the case of inelastic behaviour, seismic demand is graphically represented by the intersection of the capacity curve and the demand spectrum

#capacity curve
x2_rad = np.linspace(0,D_SDOF[11])
y2_rad = (m2*x2_rad)/(mass_eq*9.81)
x3_rad = np.linspace(D_SDOF[11],(D_SDOF[15])) 
y3_rad = (m3*x3_rad+12500)/(mass_eq*9.81)
x4_rad = np.linspace(D_SDOF[15],(D_SDOF[-1]))
y4_rad = (m4*np.ones(50))/(mass_eq*9.81)


#intersection
intersect_x_inelastic = []
intersect_y_inelastic = []

a2=[]
for i in S_d_new:
    a2.append((m2*i)/(mass_eq*9.81))

for i in range(len(S_d_new)):
    a2=np.round(a2,2)
    b2=np.round(S_a_new,2)
    if np.any(b2[i]==a2[i]):
        intersect_x_inelastic.append(np.round(S_d_new[i],0))
        intersect_y_inelastic.append(b2[i])

intersect_x_inelastic=intersect_x_inelastic[-1]
intersect_y_inelastic=intersect_y_inelastic[-1]

print('Sd, SDOF displacement demand =', intersect_x_inelastic, 'cm' )
print('Sa, SDOF acceleration demand =', intersect_y_inelastic, 'g')

#R_μ = Sae/S_ay
R_μ = intersect_y_elastic[0]/S_ay 

if T_elastic<T_C:
    μ = ((R_μ-1)*(T_C/T_elastic))+1
else:
    μ = R_μ

print('μ , ductility demand  =', np.round(μ,1) )

#print('Sd, SDOF displacement demand  =', np.round((intersect_x_elastic[0]/R_μ)*μ,2),'cm')
# Transform SDOF displacement demand to the top displacement of the MDOF model
print('Dt, top displacement of the MDOF model =', np.round((intersect_x_elastic[0]/R_μ)*μ*Γ,2),'cm')

#plot
plt.rcParams["figure.figsize"] = (6,5)
fig, ax = plt.subplots(constrained_layout=True)
ax.plot(x2_rad,y2_rad,'c-',linewidth=1.5, label='stiffness, initial')
ax.plot(x3_rad,y3_rad,'c--',linewidth=1.5, label='stiffness, post-yielding ')
ax.plot(x4_rad,y4_rad,'c-.',linewidth=1.5,label='stiffness, ultimate ')
ax.plot(rad_x_T,rad_y_T,'r-',linewidth=1,label=('T* = 0.52 s'))
ax.plot(S_de_new,S_ae_new,'k',linewidth=1,label='elastic demand spectrum')
ax.plot(S_d_new,S_a_new,'k',linewidth=1,label='inelastic demand spectrum')
ax.plot(intersect_x_elastic[0],intersect_y_elastic[0],color='m', alpha = 1, marker='o', linestyle='-',linewidth=0, markersize=8, label=("elastic yield point"))
ax.plot(intersect_x_inelastic,intersect_y_inelastic,color='r', alpha = 1, marker='o', linestyle='-',linewidth=0, markersize=5, label=("inelastic yield point"))
ax.set_xlabel('$S_d$ $=D*(cm) $')
ax.set_ylabel('$S_a$ $(g)$')
ax.grid(color='k', linestyle='--', linewidth=0.5)
ax.legend(loc='center right')
plt.xlim(0)
plt.ylim(0,3)
plt.show()
# Out:
# Sde = 9.9 cm
# Sae = 1.5 g
# Sd, SDOF displacement demand = 14.0 cm
# Sa, SDOF acceleration demand = 2.06 g
# μ , ductility demand  = 0.7
# Dt, top displacement of the MDOF model = 13.86 cm

# %%
μ
# Out:
# 0.7051191604320708

# %%
R_μ
# Out:
# 0.7431818181818183
